# %%
# %reset -f

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('logExoANDNet_c213b90a14211698.csv')
df
# Out:
#              CurrentDateTime  RSSI  RSRP  RSRQ  RSSNR  CQI          TA  Level  \
# 0    2024-02-14T15:36:59.406  -101  -100   -13    -20    7  2147483647      1
# 1    2024-02-14T15:37:00.406  -103  -103   -12    -20    7  2147483647      1
# 2    2024-02-14T15:37:01.407  -105  -105   -12    -20    7  2147483647      1
# 3    2024-02-14T15:37:02.406  -105  -105   -12    -20    7  2147483647      1
# 4    2024-02-14T15:37:03.407  -105  -105   -12    -20    7  2147483647      1
# ..                       ...   ...   ...   ...    ...  ...         ...    ...
# 433  2024-02-14T15:44:12.407   -95   -95   -14    -30    7  2147483647      1
# 434  2024-02-14T15:44:13.406   -95   -95   -14    -30    7  2147483647      1
# 435  2024-02-14T15:44:14.407   -95   -95   -14    -30    7  2147483647      1
# 436  2024-02-14T15:44:15.407   -95   -95   -14    -30    7  2147483647      1
# 437  2024-02-14T15:44:16.406   -95   -95   -14    -30    7  2147483647      1
#
# ...

# %%
array_full = np.array(df)
array_full.shape[0]
# Out:
# 438

# %%
time_line = [i for i in range(array_full.shape[0])]

# %%
# seconds_only = array_full[0,0][17:19]

# %%
plt.figure(figsize=(8, 6), dpi=120)
plt.grid(True, color='yellow', linestyle='-', linewidth=0.4)
plt.gca().set_facecolor('black')
plt.title('Graf mjerenja')

# Parameters
plt.plot(time_line, array_full[:,1], label='RSSI', linewidth=2)
plt.plot(time_line, array_full[:,2], label='RSRP', linewidth=2)
plt.plot(time_line, array_full[:,3], label='RSRQ', linewidth=2)
plt.plot(time_line, array_full[:,4], label='RSSNR', linewidth=2)

# Axis labels
plt.xlabel('Time')
plt.ylabel('Parameters')

plt.legend(loc=0)
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=120)
plt.grid(True, color='yellow', linestyle='-', linewidth=0.4)
plt.gca().set_facecolor('black')
plt.title('Graf mjerenja')

# Parameters
plt.plot(time_line, array_full[:,9], label='Bitrate (DataSource)', linewidth=2)
# plt.plot(time_line, array_full[:,11], label='Resolution (Displayed)', linewidth=2)
plt.plot(time_line, array_full[:,13], label='Rebuffering', linewidth=2)

# Axis labels
plt.xlabel('Time')
plt.ylabel('Parameters')

plt.legend(loc=0)
plt.show()

# %%
###Bolji i detaljniji prikazi logickih jedinica

# %%
plt.figure(figsize=(8, 6), dpi=120)
plt.grid(True, color='yellow', linestyle='-', linewidth=0.4)
plt.gca().set_facecolor('black')
plt.title('Graf mjerenja Bitrate')

# Parameters
plt.plot(time_line, array_full[:,9], label='Bitrate (DataSource)', linewidth=2)
# plt.plot(time_line, array_full[:,11], label='Resolution (Displayed)', linewidth=2)
#plt.plot(time_line, array_full[:,13], label='Rebuffering', linewidth=2)

# Axis labels
plt.xlabel('Time')
plt.ylabel('Parameters')

plt.legend(loc=0)
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=120)
plt.grid(True, color='yellow', linestyle='-', linewidth=0.4)
plt.gca().set_facecolor('black')
plt.title('Graf mjerenja Rebuffering')

# Parameters
#plt.plot(time_line, array_full[:,9], label='Bitrate (DataSource)', linewidth=2)
# plt.plot(time_line, array_full[:,11], label='Resolution (Displayed)', linewidth=2)
plt.plot(time_line, array_full[:,13], label='Rebuffering', linewidth=2)

# Axis labels
plt.xlabel('Time')
plt.ylabel('Parameters')

plt.legend(loc=0)
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=120)
plt.grid(True, color='yellow', linestyle='-', linewidth=0.4)
plt.gca().set_facecolor('black')
plt.title('Graf mjerenja')

# Parameters dBm values
plt.plot(time_line, array_full[:,1], label='RSSI', linewidth=2)
plt.plot(time_line, array_full[:,2], label='RSRP', linewidth=2)

# Axis labels
plt.xlabel('Time')
plt.ylabel('Parameters')

plt.legend(loc=0)
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=120)
plt.grid(True, color='yellow', linestyle='-', linewidth=0.4)
plt.gca().set_facecolor('black')
plt.title('Graf mjerenja')

# Parameters dB values
plt.plot(time_line, array_full[:,3], label='RSRQ', linewidth=2)
plt.plot(time_line, array_full[:,4], label='RSSNR', linewidth=2)

# Axis labels
plt.xlabel('Time')
plt.ylabel('Parameters')

plt.legend(loc=0)
plt.show()
